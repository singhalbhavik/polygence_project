# %%
# !pip install xbin
# %run staple_my_proteins
# Out:
# ...
#   Created wheel for xbin: filename=xbin-0.1.7-py2.py3-none-any.whl size=5972 sha256=f388484702d95f03fd0412a7786d1e0a7ab607e91f5763e128fd377c62c8291c
#   Stored in directory: /Users/bsinghal/Library/Caches/pip/wheels/84/ee/f8/684e761aa0d5f63acbc2763c7a13d20644d06e65e6e566bd71
# ...
#   Created wheel for bcc: filename=bcc-0.1.10-py2.py3-none-any.whl size=4817 sha256=f7b406d44669b6d07784fde6bbe991f82b170b8ea9b8a60ff74962374528e515
#   Stored in directory: /Users/bsinghal/Library/Caches/pip/wheels/b2/32/31/4d60e78f9b08de4ce7e37b464c1dd5d60614a57701f18622f9
# ...
#   Created wheel for homog: filename=homog-0.1.14-py2.py3-none-any.whl size=12826 sha256=bee8f50db4383c86207ccfe5f405de26c1112b6db167cc223991da89d5b77969
#   Stored in directory: /Users/bsinghal/Library/Caches/pip/wheels/0d/d3/88/3e4fa32f914af3ae31c341aa25467407d6fd685c7e0f8a1e66
# Successfully built xbin bcc homog
# ...
